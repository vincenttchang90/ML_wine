# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_score
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# %matplotlib inline

# %%
red_wine = pd.read_csv('winequality-red.csv')
white_wine = pd.read_csv('winequality-white.csv')

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wine = pd.concat([red_wine, white_wine])
wine.set_index(np.array(range(len(wine))), inplace = True)

# %%
model = PLSRegression()
score = cross_val_score(model, wine.iloc[:,:-1], wine.iloc[:,-1], cv=20, scoring='neg_mean_absolute_error')
print(score.mean())
# Out:
# -0.583223710698

# %%
model = PLSRegression(scale=False)
score0 = cross_val_score(model, wine.iloc[:,:-1], wine.iloc[:,-1], cv=20, scoring='neg_mean_absolute_error')
print(score0.mean())
# Out:
# -0.674964379926

# %% [markdown]
#  scaling seems to work better

# %%
wine.hist(figsize=(20,20), bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001734919D588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017349569F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734AB5ACF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001734AB7DCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017349DEDCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017349DEDD30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017349E4E748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017349E89C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017349ECC198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017349EF1E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017349F32748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017349F6A7B8>]], dtype=object)

# %%
test_data = wine.iloc[:,:-1].copy()

# %%
for i in test_data:
    test_data[i] = StandardScaler().fit_transform(test_data[i].values.reshape(-1,1))

test_data['quality'] = wine['quality']

# %%
outliers =[]

for i in range(len(test_data)):
    for j in test_data.iloc[i,:-1]:
        if j > 3 or j < -3:
            outliers.append(i)
            
outliers = pd.DataFrame(pd.Series(outliers).value_counts(), columns = ['count'])

for i in np.array(outliers.index):
    if outliers.loc[i].values < 1:
        outliers.drop(i, inplace=True)

print(len(outliers))
#print(test_data.loc[outliers.index])
# Out:
# 488

# %%
len(wine)
# Out:
# 6497

# %%
wine.drop(outliers.index, inplace = True)

# %%
len(wine)
# Out:
# 6009

# %%
score2 = cross_val_score(model, wine.iloc[:,:-1], wine.iloc[:,-1], cv=20, scoring='neg_mean_absolute_error')
print(score2.mean())
# Out:
# -0.66423297604

# %%
wine['quality'].value_counts()
# Out:
# 6    2636
# 5    1958
# 7    1027
# 8     184
# 4     184
# 3      15
# 9       5
# Name: quality, dtype: int64

# %%
skew1 = wine.skew()

# %%
for i in wine:
    if i == 'quality' or 'citric acid' or 'free sulfur dioxide' or 'total sulfur dioxide' or 'density':
        pass
    else:
        wine[i] = np.log1p(wine[i])

# %%
skew2 = wine.skew()

# %%
skew3 = wine.skew()

# %%
abs(skew1) > abs(skew2)
# Out:
# fixed acidity            True
# volatile acidity         True
# citric acid             False
# residual sugar           True
# chlorides                True
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                       True
# sulphates                True
# alcohol                  True
# quality                 False
# dtype: bool

# %%
skew2
# Out:
# fixed acidity           0.482686
# volatile acidity        0.922810
# citric acid            -0.290920
# residual sugar          0.346510
# chlorides               1.358683
# free sulfur dioxide    -0.821716
# total sulfur dioxide   -1.476683
# density                -0.055272
# pH                      0.110549
# sulphates               0.506755
# alcohol                 0.374006
# quality                 0.251727
# dtype: float64

# %%
wine.hist(plt)
# Out:
# fixed acidity           0.482686
# volatile acidity        0.922810
# citric acid             0.290920
# residual sugar          0.346510
# chlorides               1.358683
# free sulfur dioxide     0.821716
# total sulfur dioxide    1.476683
# density                 0.055272
# pH                      0.110549
# sulphates               0.506755
# alcohol                 0.374006
# quality                 0.251727
# dtype: float64

# %%
wine.hist(figsize=(20,20), bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001734E206C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734BEB29B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734E894C18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001734E8BF9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734D98DAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734D98DB00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001734D9EC358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734DA26828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734DA5FD68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001734DA8CAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734DACF358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001734DB063C8>]], dtype=object)

# %%
corrmat = wine.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True,annot=True);

# %%
wine.insert(5, 'sulfur ratio', wine['free sulfur dioxide'] / wine['total sulfur dioxide'])
wine.drop(['free sulfur dioxide', 'total sulfur dioxide'], axis=1, inplace=True)

# %%
corrmat = wine.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True,annot=True);

# %%
score5 = cross_val_score(model, wine.iloc[:,:-1], wine.iloc[:,-1], cv=20, scoring='neg_mean_absolute_error')
print(score5.mean())
# Out:
# -0.642746975879

# %%
wine.insert(0, 'acidity', wine['fixed acidity'] + wine['volatile acidity'] + wine['citric acid'])
wine.drop(['fixed acidity', 'volatile acidity', 'citric acid'], axis=1, inplace=True)

# %%
wine.drop(['fixed acidity', 'alcohol'], axis=1, inplace=True)

# %%
corrmat = wine.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True,annot=True);

# %%
score6 = cross_val_score(model, wine.iloc[:,:-1], wine.iloc[:,-1], cv=20, scoring='neg_mean_absolute_error')
print(score6.mean())
# Out:
# -0.67676280706

# %%
score6.mean() < score0.mean()
# Out:
# True

# %%
wine['quality'].value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
quality3 = wine[wine['quality'] == 3]
quality4 = wine[wine['quality'] == 4]
quality5 = wine[wine['quality'] == 5]
quality6 = wine[wine['quality'] == 6]
quality7 = wine[wine['quality'] == 7]
quality8 = wine[wine['quality'] == 8]
quality9 = wine[wine['quality'] == 9]

# %%
resampled_wine = []

#random_wine = np.random.choice(quality3.index, len(quality9), replace = False)
#resampled_wine.extend(random_wine)
random_wine = np.random.choice(quality4.index, len(quality8), replace = False)
resampled_wine.extend(random_wine)
random_wine = np.random.choice(quality5.index, len(quality7), replace = False)
resampled_wine.extend(random_wine)
random_wine = np.random.choice(quality6.index, len(quality7), replace = False)
resampled_wine.extend(random_wine)

resampled_wine.extend(np.array(quality7.index))
resampled_wine.extend(np.array(quality8.index))
#resampled_wine.extend(np.array(quality9.index))
data = wine.loc[resampled_wine]

# %%
len(resampled_wine)
# Out:
# 3623

# %%
len(resampled_wine)
# Out:
# 3435

# %%
len(data)
# Out:
# 3435

# %%
data['quality'].value_counts()
# Out:
# 7    1079
# 5    1079
# 6    1079
# 8     193
# 4     193
# Name: quality, dtype: int64

# %%
score6 = cross_val_score(model, data.iloc[:,:-1], data.iloc[:,-1], cv=20, scoring='neg_mean_absolute_error')
print(score6.mean())
# Out:
# -0.873822260873

# %%
corrmat = data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True,annot=True);

# %%
model.fit(data.iloc[:,:-1],data.iloc[:,-1])
# Out:
# PLSRegression(copy=True, max_iter=500, n_components=2, scale=False, tol=1e-06)

# %%
mean_absolute_error(wine.iloc[:,-1], model.predict(wine.iloc[:,:-1]))
# Out:
# 0.68008175624945422

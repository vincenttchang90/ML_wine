# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
white = pd.read_csv('winequality-white.csv')
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white.hist(bins=50, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022C59B9A278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022C59E5B630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022C59E8C6A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022C59F56780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022C59F8F780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022C59F8F7B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022C59FD8978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022C5A00F978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022C5A04ADD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022C5A06FBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022C5A0B9048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022C5A0F13C8>]], dtype=object)

# %%
red = pd.read_csv('winequality-red.csv')
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_score

# %%
pls_w = PLSRegression(scale = False)
scores0 = cross_val_score(pls_w, white.iloc[:,:-1], white.iloc[:,-1], cv=5, scoring = 'neg_mean_absolute_error')
scores0
# Out:
# array([-0.71892932, -0.69799766, -0.67869504, -0.65139362, -0.55176615])

# %%
pls_w = PLSRegression()
scores1 = cross_val_score(pls_w, white.iloc[:,:-1], white.iloc[:,-1], cv=5, scoring = 'neg_mean_absolute_error')
scores1
# Out:
# array([-0.65388759, -0.6163049 , -0.60088656, -0.59391965, -0.54922289])

# %%
scores0.mean()
# Out:
# -0.65975635707539537

# %%
scores1.mean()
# Out:
# -0.60284431780022429

# %%
white.skew()
# Out:
# fixed acidity           0.647751
# volatile acidity        1.576980
# citric acid             1.281920
# residual sugar          1.077094
# chlorides               5.023331
# free sulfur dioxide     1.406745
# total sulfur dioxide    0.390710
# density                 0.977773
# pH                      0.457783
# sulphates               0.977194
# alcohol                 0.487342
# quality                 0.155796
# dtype: float64

# %%
white.max()
# Out:
# fixed acidity            14.20000
# volatile acidity          1.10000
# citric acid               1.66000
# residual sugar           65.80000
# chlorides                 0.34600
# free sulfur dioxide     289.00000
# total sulfur dioxide    440.00000
# density                   1.03898
# pH                        3.82000
# sulphates                 1.08000
# alcohol                  14.20000
# quality                   9.00000
# dtype: float64

# %%
from scipy.stats import norm

# %%
sns.distplot(white['chlorides'], fit=norm);

# %%
test = np.log(white['chlorides'])

# %%
sns.distplot(test, fit=norm);

# %%
white['chlorides'].skew()
# Out:
# 5.0233306827597071

# %%
test.skew()
# Out:
# 1.1341336461195819

# %%
white.skew()
# Out:
# fixed acidity           0.647751
# volatile acidity        1.576980
# citric acid             1.281920
# residual sugar          1.077094
# chlorides               5.023331
# free sulfur dioxide     1.406745
# total sulfur dioxide    0.390710
# density                 0.977773
# pH                      0.457783
# sulphates               0.977194
# alcohol                 0.487342
# quality                 0.155796
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
saleprice_scaled = StandardScaler().fit_transform(white['chlorides'].reshape(-1,1));
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-100:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-1.68327372]
#  [-1.54594716]
#  [-1.50017164]
#  [-1.45439612]
#  [-1.45439612]
#  [-1.45439612]
#  [-1.45439612]
#  [-1.4086206 ]
#  [-1.4086206 ]
#  [-1.4086206 ]]
#
# outer range (high) of the distribution:
# [[  3.16893139]
#  [  3.26048243]
#  [  3.26048243]
#  [  3.26048243]
#  [  3.30625795]
#  [  3.35203347]
#  [  3.35203347]
#  [  3.35203347]
#  [  3.39780899]
#  [  3.44358451]
#  [  3.44358451]
#  [  3.48936003]
#  [  3.53513555]
#  [  3.53513555]
#  [  3.53513555]
#  [  3.53513555]
#  [  3.67246211]
#  [  3.67246211]
#  [  3.67246211]
#  [  3.71823763]
#  [  3.71823763]
#  [  3.85556419]
#  [  3.94711523]
#  [  3.99289075]
#  [  4.08444179]
#  [  4.13021731]
#  [  4.17599283]
#  [  4.17599283]
#  [  4.22176835]
#  [  4.22176835]
#  [  4.40487043]
#  [  4.40487043]
#  [  4.40487043]
#  [  4.49642147]
#  [  4.54219699]
#  [  4.58797251]
#  [  4.63374803]
#  [  4.63374803]
#  [  4.67952355]
#  [  4.72529907]
#  [  4.77107459]
#  [  4.86262563]
#  [  4.86262563]
#  [  4.95417667]
#  [  5.04572771]
#  [  5.09150323]
#  [  5.09150323]
#  [  5.09150323]
#  [  5.09150323]
#  [  5.13727875]
#  [  5.22882979]
#  [  5.22882979]
#  [  5.54925843]
#  [  5.54925843]
#  [  5.59503395]
#  [  5.59503395]
#  [  5.59503395]
#  [  5.64080947]
#  [  5.64080947]
#  [  5.68658499]
#  [  5.68658499]
#  [  5.73236051]
#  [  5.77813603]
#  [  5.77813603]
#  [  5.82391155]
#  [  5.82391155]
#  [  5.86968707]
#  [  5.86968707]
#  [  5.91546259]
#  [  5.91546259]
#  [  5.96123811]
#  [  5.96123811]
#  [  6.09856467]
#  [  6.14434019]
#  [  6.32744226]
#  [  6.32744226]
#  [  6.37321778]
#  [  6.37321778]
#  [  6.4189933 ]
#  [  6.78519746]
#  [  6.92252402]
#  [  6.92252402]
#  [  7.05985058]
#  [  7.1056261 ]
#  [  7.1056261 ]
#  [  7.24295266]
#  [  7.42605474]
#  [  7.42605474]
#  [  7.47183026]
#  [  7.5633813 ]
#  [  7.60915682]
#  [  7.83803442]
#  [  8.84509586]
#  [  8.89087138]
#  [  9.07397346]
#  [  9.57750418]
#  [ 10.3099125 ]
#  [ 11.17964737]
#  [ 11.68317809]
#  [ 13.74307649]]
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
nooutliers = saleprice_scaled[saleprice_scaled < 3]

# %%
nooutliers1 = pd.DataFrame(data=nooutliers)

# %%
nooutliers1.skew()
# Out:
# 0    1.04894
# dtype: float64

# %%
sns.distplot(nooutliers1, fit=norm);

# %%
nooutliers1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4796 entries, 0 to 4795
# Data columns (total 1 columns):
# 0    4796 non-null float64
# dtypes: float64(1)
# memory usage: 37.5 KB

# %%
white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df = white.copy()

# %%
df_scaled = StandardScaler().fit(df.iloc[:,:-1])

# %%
saleprice_scaled = StandardScaler().fit_transform(white['volatile acidity'].reshape(-1,1));
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-100:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-1.96698494]
#  [-1.96698494]
#  [-1.96698494]
#  [-1.96698494]
#  [-1.91737402]
#  [-1.8677631 ]
#  [-1.76854125]
#  [-1.76854125]
#  [-1.76854125]
#  [-1.76854125]]
#
# outer range (high) of the distribution:
# [[ 2.79566358]
#  [ 2.79566358]
#  [ 2.79566358]
#  [ 2.79566358]
#  [ 2.79566358]
#  [ 2.79566358]
#  [ 2.79566358]
#  [ 2.79566358]
#  [ 2.89488543]
#  [ 2.89488543]
#  [ 2.89488543]
#  [ 2.89488543]
#  [ 2.99410727]
#  [ 2.99410727]
#  [ 2.99410727]
#  [ 2.99410727]
#  [ 2.99410727]
#  [ 2.99410727]
#  [ 2.99410727]
#  [ 3.04371819]
#  [ 3.04371819]
#  [ 3.09332911]
#  [ 3.09332911]
#  [ 3.09332911]
#  [ 3.09332911]
#  [ 3.14294004]
#  [ 3.14294004]
#  [ 3.19255096]
#  [ 3.19255096]
#  [ 3.19255096]
#  [ 3.19255096]
#  [ 3.19255096]
#  [ 3.19255096]
#  [ 3.19255096]
#  [ 3.2917728 ]
#  [ 3.2917728 ]
#  [ 3.2917728 ]
#  [ 3.2917728 ]
#  [ 3.2917728 ]
#  [ 3.2917728 ]
#  [ 3.2917728 ]
#  [ 3.34138372]
#  [ 3.34138372]
#  [ 3.34138372]
#  [ 3.34138372]
#  [ 3.39099465]
#  [ 3.39099465]
#  [ 3.39099465]
#  [ 3.39099465]
#  [ 3.39099465]
#  [ 3.49021649]
#  [ 3.49021649]
#  [ 3.58943834]
#  [ 3.58943834]
#  [ 3.58943834]
#  [ 3.58943834]
#  [ 3.58943834]
#  [ 3.58943834]
#  [ 3.58943834]
#  [ 3.68866018]
#  [ 3.68866018]
#  [ 3.7382711 ]
#  [ 3.7382711 ]
#  [ 3.7382711 ]
#  [ 3.78788202]
#  [ 3.78788202]
#  [ 3.78788202]
#  [ 3.78788202]
#  [ 3.88710387]
#  [ 3.88710387]
#  [ 3.88710387]
#  [ 3.88710387]
#  [ 3.88710387]
#  [ 3.98632571]
#  [ 3.98632571]
#  [ 3.98632571]
#  [ 4.03593663]
#  [ 4.08554756]
#  [ 4.08554756]
#  [ 4.13515848]
#  [ 4.13515848]
#  [ 4.13515848]
#  [ 4.23438032]
#  [ 4.23438032]
#  [ 4.28399124]
#  [ 4.48243493]
#  [ 4.58165678]
#  [ 4.68087862]
#  [ 4.78010047]
#  [ 4.78010047]
#  [ 4.97854415]
#  [ 5.02815508]
#  [ 5.32582061]
#  [ 5.67309706]
#  [ 6.21881721]
#  [ 6.26842813]
#  [ 6.46687182]
#  [ 6.81414827]
#  [ 7.21103565]
#  [ 8.15364317]]
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
nooutlier0 = saleprice_scaled[saleprice_scaled < 3]

# %%
nooutlier0 = pd.DataFrame(nooutlier0)

# %%
low_range = nooutlier0[nooutlier0[:,0].argsort()][:10]
high_range= nooutlier0[nooutlier0[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-3818a106fead> in <module>()
# ----> 1 low_range = nooutlier0[nooutlier0[:,0].argsort()][:10]
#       2 high_range= nooutlier0[nooutlier0[:,0].argsort()][-10:]
#       3 print('outer range (low) of the distribution:')
#       4 print(low_range)
#       5 print('\nouter range (high) of the distribution:')
#
# IndexError: too many indices for array

# %%
len(nooutlier0)
# Out:
# 4817

# %%
corrmat = white.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True,annot=True);

# %%
df = StandardScaler().fit_transform(white.iloc[:,:-1])

# %%
for i in df:
    if i == 'quality':
        break
    df[i] = StandardScaler().fit_transform(df[i].values.reshape(-1,1))

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.172097         -0.081770     0.213280        2.821349  -0.035355
# 1      -0.657501          0.215896     0.048001       -0.944765   0.147747
# 2       1.475751          0.017452     0.543838        0.100282   0.193523
# 3       0.409125         -0.478657    -0.117278        0.415768   0.559727
# 4       0.409125         -0.478657    -0.117278        0.415768   0.559727
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.569932              0.744565  2.331512 -1.246921  -0.349184
# 1            -1.253019             -0.149685 -0.009154  0.740029   0.001342
# 2            -0.312141             -0.973336  0.358665  0.475102  -0.436816
# 3             0.687541              1.121091  0.525855  0.011480  -0.787342
# 4             0.687541              1.121091  0.525855  0.011480  -0.787342
#
#     alcohol  quality
# 0 -1.393152        6
# 1 -0.824276        6
# 2 -0.336667        6
# 3 -0.499203        6
# 4 -0.499203        6

# %%
for i in df.iloc[0,:-1]:
    print(i)
# Out:
# 0.172096961
# -0.0817699008083
# 0.213280201791
# 2.82134916946
# -0.0353550003591
# 0.56993157686
# 0.744565034621
# 2.33151201465
# -1.24692128107
# -0.349184257308
# -1.39315245993

# %%
len(df)
# Out:
# 4882

# %%
for i in range(len(df)):
    if i == 0:
        print('yes')
    if i == 4898:
        print('no')
# Out:
# yes

# %%
len(white)
# Out:
# 4898

# %%
droplist =[]

# %%
for i in range(len(df)):
    for j in df.iloc[i,:-1]:
        if j >= 3 or j <= -3:
            print(df.loc[i])
            droplist.append(i)
# Out:
# fixed acidity          -0.776015
# volatile acidity        3.787882
# citric acid             1.204955
# residual sugar         -1.023637
# chlorides              -0.767763
# free sulfur dioxide    -0.370946
# total sulfur dioxide   -1.491059
# density                -1.614182
# pH                      0.938724
# sulphates              -0.874973
# alcohol                 1.857572
# quality                 8.000000
# Name: 17, dtype: float64
# fixed acidity          -0.776015
# volatile acidity        3.787882
# citric acid             1.204955
# residual sugar         -1.023637
# chlorides              -0.767763
# free sulfur dioxide    -0.370946
# total sulfur dioxide   -1.491059
# density                -1.614182
# pH                      0.938724
# sulphates              -0.874973
# alcohol                 1.857572
# quality                 8.000000
# Name: 20, dtype: float64
# fixed acidity           0.883181
# volatile acidity        3.887104
# citric acid            -1.604790
# residual sugar         -0.964483
# chlorides               1.292135
# free sulfur dioxide    -0.606165
# total sulfur dioxide    0.697499
# density                -0.109468
# pH                     -0.915763
# sulphates               0.176605
# alcohol                -0.986812
# quality                 5.000000
# Name: 23, dtype: float64
# fixed acidity          -0.183445
# volatile acidity       -0.478657
# citric acid             0.461199
# residual sugar         -0.767304
# chlorides               5.778136
# free sulfur dioxide     1.628419
# total sulfur dioxide    0.462170
# density                -0.109468
# pH                     -0.518373
# sulphates              -1.137868
# alcohol                -0.905544
# quality                 6.000000
# Name: 40, dtype: float64
# fixed acidity          -0.183445
# volatile acidity       -0.379435
# citric acid             0.461199
# residual sugar         -0.688433
# chlorides               5.823912
# free sulfur dioxide     1.628419
# total sulfur dioxide    0.438638
# density                -0.109468
# pH                     -0.584605
# sulphates              -1.313131
# alcohol                -0.905544
# quality                 6.000000
# Name: 41, dtype: float64
# fixed acidity          -0.064931
# volatile acidity       -0.776323
# citric acid             2.113990
# residual sugar         -1.082790
# chlorides               4.633748
# free sulfur dioxide     0.158298
# total sulfur dioxide   -0.149685
# density                -0.343535
# pH                     -0.915763
# sulphates              -0.962605
# alcohol                -1.149348
# quality                 6.000000
# Name: 54, dtype: float64
# fixed acidity          -1.013043
# volatile acidity       -0.081770
# citric acid            -0.447836
# residual sugar         -0.313793
# chlorides               0.788604
# free sulfur dioxide    -0.253336
# total sulfur dioxide    1.474084
# density                 0.793360
# pH                      3.323064
# sulphates               1.929235
# alcohol                -0.417935
# quality                 5.000000
# Name: 72, dtype: float64
# fixed acidity           3.490489
# volatile acidity        0.811227
# citric acid             1.039676
# residual sugar          0.810126
# chlorides              -0.355784
# free sulfur dioxide    -1.841067
# total sulfur dioxide   -1.302796
# density                 0.525855
# pH                     -1.975470
# sulphates              -1.663657
# alcohol                -0.336667
# quality                 4.000000
# Name: 98, dtype: float64
# fixed acidity          -0.538987
# volatile acidity        3.142940
# citric acid            -1.604790
# residual sugar         -0.234922
# chlorides               0.559727
# free sulfur dioxide    -1.194214
# total sulfur dioxide   -0.973336
# density                 0.358665
# pH                      1.269882
# sulphates              -1.137868
# alcohol                -1.230616
# quality                 4.000000
# Name: 147, dtype: float64
# fixed acidity           1.594265
# volatile acidity       -0.478657
# citric acid             0.543838
# residual sugar          0.218589
# chlorides               0.147747
# free sulfur dioxide    -1.370628
# total sulfur dioxide   -1.467526
# density                 0.860236
# pH                     -0.849531
# sulphates               3.068445
# alcohol                -0.661739
# quality                 6.000000
# Name: 154, dtype: float64
# fixed acidity           3.490489
# volatile acidity        1.406558
# citric acid             1.204955
# residual sugar          0.681960
# chlorides              -0.538886
# free sulfur dioxide    -1.782262
# total sulfur dioxide   -0.667408
# density                 0.592731
# pH                     -2.107933
# sulphates              -1.751289
# alcohol                -0.417935
# quality                 5.000000
# Name: 169, dtype: float64
# fixed acidity          -1.013043
# volatile acidity        3.887104
# citric acid            -2.183266
# residual sugar         -1.023637
# chlorides               0.651278
# free sulfur dioxide    -1.547043
# total sulfur dioxide   -0.714474
# density                -0.310097
# pH                     -0.518373
# sulphates              -1.225500
# alcohol                -1.474421
# quality                 4.000000
# Name: 178, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        0.017452
# citric acid             0.543838
# residual sugar          3.077682
# chlorides               0.101972
# free sulfur dioxide     0.746346
# total sulfur dioxide    0.673966
# density                 2.331512
# pH                     -1.710543
# sulphates               0.088973
# alcohol                -1.474421
# quality                 5.000000
# Name: 182, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        0.017452
# citric acid             0.543838
# residual sugar          3.077682
# chlorides               0.101972
# free sulfur dioxide     0.746346
# total sulfur dioxide    0.673966
# density                 2.331512
# pH                     -1.710543
# sulphates               0.088973
# alcohol                -1.474421
# quality                 5.000000
# Name: 191, dtype: float64
# fixed acidity          -0.538987
# volatile acidity        0.116674
# citric acid             0.874397
# residual sugar         -0.550408
# chlorides               7.059851
# free sulfur dioxide     2.334077
# total sulfur dioxide    1.003427
# density                 0.057722
# pH                     -1.114458
# sulphates              -0.699710
# alcohol                -1.149348
# quality                 5.000000
# Name: 194, dtype: float64
# fixed acidity          -0.538987
# volatile acidity        0.215896
# citric acid             0.957036
# residual sugar         -0.570126
# chlorides               6.922524
# free sulfur dioxide     2.392882
# total sulfur dioxide    0.979894
# density                 0.057722
# pH                     -1.114458
# sulphates              -0.874973
# alcohol                -1.149348
# quality                 6.000000
# Name: 195, dtype: float64
# fixed acidity          -0.538987
# volatile acidity        0.116674
# citric acid             0.874397
# residual sugar         -0.550408
# chlorides               6.922524
# free sulfur dioxide     2.334077
# total sulfur dioxide    1.050493
# density                 0.057722
# pH                     -1.180690
# sulphates              -0.962605
# alcohol                -1.149348
# quality                 5.000000
# Name: 196, dtype: float64
# fixed acidity           3.964545
# volatile acidity        1.605001
# citric acid             4.510536
# residual sugar         -0.037743
# chlorides               0.147747
# free sulfur dioxide    -0.900190
# total sulfur dioxide   -0.337948
# density                 0.927112
# pH                     -1.313153
# sulphates               0.176605
# alcohol                -0.499203
# quality                 4.000000
# Name: 207, dtype: float64
# fixed acidity           3.964545
# volatile acidity        1.605001
# citric acid             4.510536
# residual sugar         -0.037743
# chlorides               0.147747
# free sulfur dioxide    -0.900190
# total sulfur dioxide   -0.337948
# density                 0.927112
# pH                     -1.313153
# sulphates               0.176605
# alcohol                -0.499203
# quality                 4.000000
# Name: 207, dtype: float64
# fixed acidity           0.409125
# volatile acidity        4.035937
# citric acid            -1.026313
# residual sugar          0.612947
# chlorides               1.109033
# free sulfur dioxide    -0.135727
# total sulfur dioxide    0.791631
# density                 1.027427
# pH                     -1.246921
# sulphates               0.527131
# alcohol                -1.149348
# quality                 6.000000
# Name: 221, dtype: float64
# fixed acidity           0.290611
# volatile acidity       -0.280214
# citric acid            -0.117278
# residual sugar          0.770690
# chlorides              -0.218457
# free sulfur dioxide     1.804833
# total sulfur dioxide    3.144919
# density                 0.960550
# pH                     -0.120983
# sulphates               0.264236
# alcohol                -1.149348
# quality                 6.000000
# Name: 227, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        3.589438
# citric acid            -2.100627
# residual sugar          0.652383
# chlorides               0.742829
# free sulfur dioxide    -0.547361
# total sulfur dioxide    0.085644
# density                 1.060865
# pH                      1.203650
# sulphates              -0.261553
# alcohol                -1.311884
# quality                 4.000000
# Name: 230, dtype: float64
# fixed acidity          -1.131557
# volatile acidity       -0.677101
# citric acid            -0.447836
# residual sugar         -0.353229
# chlorides               0.330849
# free sulfur dioxide     0.275907
# total sulfur dioxide    1.427019
# density                 0.793360
# pH                      3.521759
# sulphates               1.841604
# alcohol                -0.417935
# quality                 4.000000
# Name: 250, dtype: float64
# fixed acidity          -1.842641
# volatile acidity        3.043718
# citric acid            -2.183266
# residual sugar          0.139718
# chlorides              -0.081131
# free sulfur dioxide    -0.076922
# total sulfur dioxide    0.156243
# density                 0.158036
# pH                      1.004955
# sulphates               0.702394
# alcohol                -0.661739
# quality                 6.000000
# Name: 268, dtype: float64
# fixed acidity          -1.724127
# volatile acidity        3.093329
# citric acid            -2.183266
# residual sugar          0.120000
# chlorides              -0.035355
# free sulfur dioxide     0.040688
# total sulfur dioxide    0.203309
# density                 0.124598
# pH                      1.004955
# sulphates               0.702394
# alcohol                -0.661739
# quality                 6.000000
# Name: 269, dtype: float64
# fixed acidity          -1.961155
# volatile acidity        3.192551
# citric acid            -2.183266
# residual sugar          0.120000
# chlorides              -0.081131
# free sulfur dioxide    -0.135727
# total sulfur dioxide    0.203309
# density                 0.124598
# pH                      0.938724
# sulphates               0.790026
# alcohol                -0.661739
# quality                 5.000000
# Name: 271, dtype: float64
# fixed acidity           2.660891
# volatile acidity        3.093329
# citric acid             0.378559
# residual sugar         -0.944765
# chlorides               0.925931
# free sulfur dioxide    -0.076922
# total sulfur dioxide    1.026960
# density                 0.927112
# pH                      0.276407
# sulphates              -0.962605
# alcohol                -1.636957
# quality                 3.000000
# Name: 294, dtype: float64
# fixed acidity           1.712779
# volatile acidity        1.108892
# citric acid             3.023025
# residual sugar          0.829844
# chlorides              -0.035355
# free sulfur dioxide    -0.135727
# total sulfur dioxide    0.721032
# density                 1.194617
# pH                     -0.650836
# sulphates               0.702394
# alcohol                -0.905544
# quality                 5.000000
# Name: 296, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        0.017452
# citric acid             2.196629
# residual sugar         -1.043355
# chlorides               3.947115
# free sulfur dioxide     0.393517
# total sulfur dioxide   -0.267349
# density                -0.209783
# pH                     -0.650836
# sulphates              -0.436816
# alcohol                -1.149348
# quality                 6.000000
# Name: 315, dtype: float64
# fixed acidity           0.764667
# volatile acidity       -0.081770
# citric acid            -0.199917
# residual sugar         -0.116614
# chlorides               0.513951
# free sulfur dioxide     5.627148
# total sulfur dioxide    4.109768
# density                 0.191474
# pH                     -0.054751
# sulphates               0.877657
# alcohol                -0.011595
# quality                 5.000000
# Name: 325, dtype: float64
# fixed acidity           0.764667
# volatile acidity       -0.081770
# citric acid            -0.199917
# residual sugar         -0.116614
# chlorides               0.513951
# free sulfur dioxide     5.627148
# total sulfur dioxide    4.109768
# density                 0.191474
# pH                     -0.054751
# sulphates               0.877657
# alcohol                -0.011595
# quality                 5.000000
# Name: 325, dtype: float64
# fixed acidity          -0.301959
# volatile acidity       -0.974766
# citric acid             0.130641
# residual sugar         -0.964483
# chlorides               0.147747
# free sulfur dioxide     0.805151
# total sulfur dioxide    0.062111
# density                -0.209783
# pH                      1.601040
# sulphates               3.156077
# alcohol                -0.255399
# quality                 7.000000
# Name: 339, dtype: float64
# fixed acidity           3.727517
# volatile acidity       -0.776323
# citric acid             0.461199
# residual sugar         -0.984201
# chlorides               0.193523
# free sulfur dioxide    -0.958994
# total sulfur dioxide    0.320973
# density                -0.009154
# pH                     -1.246921
# sulphates              -0.612079
# alcohol                -0.092863
# quality                 6.000000
# Name: 358, dtype: float64
# fixed acidity          -0.301959
# volatile acidity        6.218817
# citric acid            -1.191592
# residual sugar         -1.102508
# chlorides               0.101972
# free sulfur dioxide    -1.076604
# total sulfur dioxide    1.544683
# density                -0.209783
# pH                      1.004955
# sulphates               0.614763
# alcohol                -0.417935
# quality                 5.000000
# Name: 372, dtype: float64
# fixed acidity          -0.064931
# volatile acidity       -0.081770
# citric acid            -1.770069
# residual sugar         -1.003919
# chlorides              -0.264233
# free sulfur dioxide     3.039735
# total sulfur dioxide    0.697499
# density                -0.677916
# pH                     -0.054751
# sulphates              -0.699710
# alcohol                -0.417935
# quality                 5.000000
# Name: 395, dtype: float64
# fixed acidity          -0.064931
# volatile acidity       -0.081770
# citric acid            -1.770069
# residual sugar         -1.003919
# chlorides              -0.264233
# free sulfur dioxide     3.039735
# total sulfur dioxide    0.697499
# density                -0.677916
# pH                     -0.054751
# sulphates              -0.699710
# alcohol                -0.417935
# quality                 5.000000
# Name: 405, dtype: float64
# fixed acidity           0.409125
# volatile acidity        3.192551
# citric acid            -1.108952
# residual sugar          0.691818
# chlorides               1.109033
# free sulfur dioxide    -0.841385
# total sulfur dioxide    0.838697
# density                 1.027427
# pH                     -1.048226
# sulphates               0.439499
# alcohol                -1.149348
# quality                 5.000000
# Name: 450, dtype: float64
# fixed acidity           2.068321
# volatile acidity        0.910449
# citric acid             3.023025
# residual sugar          1.135471
# chlorides              -0.310008
# free sulfur dioxide    -0.841385
# total sulfur dioxide    0.462170
# density                 1.428684
# pH                     -1.246921
# sulphates               2.104498
# alcohol                -0.986812
# quality                 6.000000
# Name: 470, dtype: float64
# fixed acidity           -0.776015
# volatile acidity         0.910449
# citric acid             -0.282557
# residual sugar           0.041129
# chlorides               13.743076
# free sulfur dioxide      2.569296
# total sulfur dioxide     1.450552
# density                  0.458979
# pH                       0.673797
# sulphates                0.790026
# alcohol                 -0.743008
# quality                  5.000000
# Name: 484, dtype: float64
# fixed acidity          -1.131557
# volatile acidity        3.390995
# citric acid            -0.447836
# residual sugar         -0.570126
# chlorides              -0.310008
# free sulfur dioxide     1.157980
# total sulfur dioxide    0.320973
# density                -1.112611
# pH                      1.667272
# sulphates              -0.436816
# alcohol                 1.207427
# quality                 6.000000
# Name: 508, dtype: float64
# fixed acidity          -1.131557
# volatile acidity        0.414339
# citric acid             0.461199
# residual sugar         -0.609561
# chlorides               3.123156
# free sulfur dioxide    -0.664970
# total sulfur dioxide    0.038578
# density                -0.209783
# pH                     -0.650836
# sulphates              -0.349184
# alcohol                -1.068080
# quality                 6.000000
# Name: 525, dtype: float64
# fixed acidity          -0.538987
# volatile acidity       -0.974766
# citric acid             1.204955
# residual sugar         -0.471536
# chlorides               6.418993
# free sulfur dioxide     1.687224
# total sulfur dioxide    0.273907
# density                 0.158036
# pH                     -0.849531
# sulphates              -0.787342
# alcohol                -0.986812
# quality                 5.000000
# Name: 531, dtype: float64
# fixed acidity           1.831293
# volatile acidity        0.712005
# citric acid             3.105664
# residual sugar          1.145330
# chlorides               0.010421
# free sulfur dioxide    -0.782580
# total sulfur dioxide    0.509236
# density                 1.395246
# pH                     -1.379385
# sulphates               1.403446
# alcohol                -0.905544
# quality                 5.000000
# Name: 556, dtype: float64
# fixed acidity          -0.183445
# volatile acidity        0.215896
# citric acid             0.130641
# residual sugar         -0.984201
# chlorides               6.144340
# free sulfur dioxide     0.040688
# total sulfur dioxide    0.509236
# density                -0.109468
# pH                     -0.518373
# sulphates               0.439499
# alcohol                -0.905544
# quality                 6.000000
# Name: 600, dtype: float64
# fixed acidity          -0.420473
# volatile acidity        0.513561
# citric acid             3.188304
# residual sugar         -1.043355
# chlorides               0.697053
# free sulfur dioxide    -1.664653
# total sulfur dioxide    0.297440
# density                -0.343535
# pH                     -0.650836
# sulphates               0.702394
# alcohol                -0.824276
# quality                 4.000000
# Name: 646, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        0.116674
# citric acid            -1.439511
# residual sugar         -0.984201
# chlorides              -0.355784
# free sulfur dioxide     5.127307
# total sulfur dioxide    2.262436
# density                -0.611040
# pH                     -0.253446
# sulphates              -0.173921
# alcohol                -0.417935
# quality                 4.000000
# Name: 659, dtype: float64
# fixed acidity          -0.538987
# volatile acidity       -0.081770
# citric acid            -0.117278
# residual sugar         -0.372947
# chlorides               8.890871
# free sulfur dioxide     1.510809
# total sulfur dioxide    0.838697
# density                 0.258351
# pH                     -0.452141
# sulphates              -0.086290
# alcohol                -0.905544
# quality                 5.000000
# Name: 683, dtype: float64
# fixed acidity           -0.064931
# volatile acidity         3.887104
# citric acid             -0.282557
# residual sugar           1.303073
# chlorides               11.179647
# free sulfur dioxide     -0.782580
# total sulfur dioxide     1.285821
# density                  1.462122
# pH                      -0.717068
# sulphates                1.578709
# alcohol                 -1.230616
# quality                  4.000000
# Name: 687, dtype: float64
# fixed acidity           -0.064931
# volatile acidity         3.887104
# citric acid             -0.282557
# residual sugar           1.303073
# chlorides               11.179647
# free sulfur dioxide     -0.782580
# total sulfur dioxide     1.285821
# density                  1.462122
# pH                      -0.717068
# sulphates                1.578709
# alcohol                 -1.230616
# quality                  4.000000
# Name: 687, dtype: float64
# fixed acidity           1.831293
# volatile acidity        1.208114
# citric acid             3.023025
# residual sugar          1.322791
# chlorides              -0.172682
# free sulfur dioxide    -0.370946
# total sulfur dioxide    1.379953
# density                 1.328369
# pH                     -0.849531
# sulphates               1.315815
# alcohol                -0.661739
# quality                 5.000000
# Name: 700, dtype: float64
# fixed acidity          -1.013043
# volatile acidity        0.513561
# citric acid            -0.530476
# residual sugar         -1.102508
# chlorides               6.373218
# free sulfur dioxide    -1.370628
# total sulfur dioxide    1.168157
# density                -0.544164
# pH                     -0.452141
# sulphates               1.140552
# alcohol                -0.905544
# quality                 5.000000
# Name: 729, dtype: float64
# fixed acidity            0.646153
# volatile acidity        -0.776323
# citric acid             10.956420
# residual sugar          -0.846176
# chlorides               -1.088192
# free sulfur dioxide     -0.076922
# total sulfur dioxide    -0.596809
# density                 -0.794949
# pH                       0.475102
# sulphates                0.527131
# alcohol                  1.369963
# quality                  6.000000
# Name: 745, dtype: float64
# fixed acidity          -0.064931
# volatile acidity       -0.577879
# citric acid             0.295920
# residual sugar          1.736866
# chlorides               0.239298
# free sulfur dioxide     1.922443
# total sulfur dioxide    0.932828
# density                 1.779784
# pH                      1.402345
# sulphates               3.156077
# alcohol                -0.986812
# quality                 6.000000
# Name: 757, dtype: float64
# fixed acidity           0.290611
# volatile acidity       -1.371654
# citric acid             0.543838
# residual sugar         -1.023637
# chlorides               0.239298
# free sulfur dioxide     1.157980
# total sulfur dioxide   -0.055553
# density                -0.276659
# pH                      0.740029
# sulphates               4.120024
# alcohol                -0.580471
# quality                 7.000000
# Name: 758, dtype: float64
# fixed acidity           0.290611
# volatile acidity       -1.470876
# citric acid             0.543838
# residual sugar         -1.023637
# chlorides               0.056196
# free sulfur dioxide     1.099175
# total sulfur dioxide   -0.102619
# density                -0.276659
# pH                      0.740029
# sulphates               4.207655
# alcohol                -0.580471
# quality                 7.000000
# Name: 759, dtype: float64
# fixed acidity          -0.301959
# volatile acidity       -1.173210
# citric acid             1.948711
# residual sugar         -1.043355
# chlorides               3.855564
# free sulfur dioxide     1.334395
# total sulfur dioxide    0.038578
# density                -0.443849
# pH                     -0.452141
# sulphates              -0.874973
# alcohol                -0.986812
# quality                 7.000000
# Name: 771, dtype: float64
# fixed acidity          -0.301959
# volatile acidity       -0.677101
# citric acid             2.196629
# residual sugar         -1.043355
# chlorides               4.084442
# free sulfur dioxide     1.510809
# total sulfur dioxide    0.132710
# density                -0.443849
# pH                     -0.452141
# sulphates              -0.874973
# alcohol                -0.986812
# quality                 7.000000
# Name: 772, dtype: float64
# fixed acidity          -0.538987
# volatile acidity       -0.528268
# citric acid             1.204955
# residual sugar         -0.826458
# chlorides               3.168931
# free sulfur dioxide    -0.370946
# total sulfur dioxide   -0.808605
# density                -0.744792
# pH                      0.342639
# sulphates               0.790026
# alcohol                 1.288695
# quality                 6.000000
# Name: 775, dtype: float64
# fixed acidity           0.527639
# volatile acidity        3.738271
# citric acid            -1.108952
# residual sugar          0.750972
# chlorides               1.154809
# free sulfur dioxide    -0.429751
# total sulfur dioxide    1.732946
# density                 1.027427
# pH                     -1.511848
# sulphates               0.790026
# alcohol                -1.068080
# quality                 6.000000
# Name: 821, dtype: float64
# fixed acidity           0.527639
# volatile acidity       -0.726712
# citric acid            -0.199917
# residual sugar         -0.925047
# chlorides               0.651278
# free sulfur dioxide    -0.076922
# total sulfur dioxide   -0.667408
# density                 0.759922
# pH                      3.521759
# sulphates               1.753972
# alcohol                -0.011595
# quality                 6.000000
# Name: 830, dtype: float64
# fixed acidity           0.527639
# volatile acidity       -0.726712
# citric acid            -0.199917
# residual sugar         -0.925047
# chlorides               0.651278
# free sulfur dioxide    -0.076922
# total sulfur dioxide   -0.667408
# density                 0.759922
# pH                      3.521759
# sulphates               1.753972
# alcohol                -0.011595
# quality                 6.000000
# Name: 834, dtype: float64
# fixed acidity           0.053583
# volatile acidity       -0.974766
# citric acid             0.213280
# residual sugar         -1.003919
# chlorides              -0.447335
# free sulfur dioxide     0.275907
# total sulfur dioxide   -0.502678
# density                -0.209783
# pH                      0.541334
# sulphates               4.032392
# alcohol                -0.824276
# quality                 7.000000
# Name: 852, dtype: float64
# fixed acidity           0.053583
# volatile acidity       -0.974766
# citric acid             0.213280
# residual sugar         -1.003919
# chlorides              -0.447335
# free sulfur dioxide     0.275907
# total sulfur dioxide   -0.502678
# density                -0.209783
# pH                      0.541334
# sulphates               4.032392
# alcohol                -0.824276
# quality                 7.000000
# Name: 854, dtype: float64
# fixed acidity          -0.301959
# volatile acidity        0.215896
# citric acid            -0.282557
# residual sugar         -0.313793
# chlorides               5.686585
# free sulfur dioxide     1.452004
# total sulfur dioxide    0.650433
# density                 0.191474
# pH                     -0.054751
# sulphates              -0.173921
# alcohol                -0.905544
# quality                 5.000000
# Name: 859, dtype: float64
# fixed acidity           0.053583
# volatile acidity       -0.974766
# citric acid             0.213280
# residual sugar         -1.003919
# chlorides              -0.447335
# free sulfur dioxide     0.275907
# total sulfur dioxide   -0.502678
# density                -0.209783
# pH                      0.541334
# sulphates               4.032392
# alcohol                -0.824276
# quality                 7.000000
# Name: 866, dtype: float64
# fixed acidity           4.083059
# volatile acidity       -1.073988
# citric acid             1.122315
# residual sugar         -0.984201
# chlorides              -0.401559
# free sulfur dioxide    -1.782262
# total sulfur dioxide   -2.479440
# density                -0.042592
# pH                     -1.975470
# sulphates              -1.838920
# alcohol                -0.743008
# quality                 3.000000
# Name: 873, dtype: float64
# fixed acidity          -1.013043
# volatile acidity        0.017452
# citric acid             0.048001
# residual sugar         -0.944765
# chlorides               3.352033
# free sulfur dioxide    -0.135727
# total sulfur dioxide   -0.808605
# density                -0.644478
# pH                      0.011480
# sulphates              -0.962605
# alcohol                -0.255399
# quality                 6.000000
# Name: 877, dtype: float64
# fixed acidity          -0.776015
# volatile acidity       -1.173210
# citric acid             1.700792
# residual sugar         -0.984201
# chlorides               3.672462
# free sulfur dioxide     0.099493
# total sulfur dioxide   -0.667408
# density                -0.276659
# pH                      0.276407
# sulphates              -1.050236
# alcohol                -1.311884
# quality                 6.000000
# Name: 878, dtype: float64
# fixed acidity          -1.724127
# volatile acidity        3.142940
# citric acid            -1.935348
# residual sugar         -0.708151
# chlorides              -0.172682
# free sulfur dioxide    -0.547361
# total sulfur dioxide   -1.373395
# density                -0.276659
# pH                      1.137419
# sulphates              -0.962605
# alcohol                -0.986812
# quality                 5.000000
# Name: 926, dtype: float64
# fixed acidity           1.594265
# volatile acidity        0.662394
# citric acid             5.502211
# residual sugar          2.328402
# chlorides               0.056196
# free sulfur dioxide     1.157980
# total sulfur dioxide    1.568216
# density                 1.880098
# pH                     -1.511848
# sulphates              -0.524447
# alcohol                -0.743008
# quality                 5.000000
# Name: 946, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        4.234380
# citric acid            -0.695755
# residual sugar         -0.629279
# chlorides               0.101972
# free sulfur dioxide    -1.488238
# total sulfur dioxide   -1.914651
# density                 0.659608
# pH                      1.137419
# sulphates               0.264236
# alcohol                -0.824276
# quality                 4.000000
# Name: 948, dtype: float64
# fixed acidity           0.290611
# volatile acidity       -1.470876
# citric acid             0.378559
# residual sugar         -0.905330
# chlorides               0.010421
# free sulfur dioxide    -1.253019
# total sulfur dioxide   -0.573277
# density                -0.510725
# pH                      0.872492
# sulphates               3.594234
# alcohol                 0.963623
# quality                 6.000000
# Name: 974, dtype: float64
# fixed acidity          -1.013043
# volatile acidity       -0.776323
# citric acid             3.105664
# residual sugar         -0.944765
# chlorides               4.771075
# free sulfur dioxide    -1.488238
# total sulfur dioxide   -1.985250
# density                -0.443849
# pH                     -0.452141
# sulphates              -0.173921
# alcohol                -0.580471
# quality                 5.000000
# Name: 979, dtype: float64
# fixed acidity          -1.013043
# volatile acidity       -0.776323
# citric acid             3.105664
# residual sugar         -0.944765
# chlorides               4.771075
# free sulfur dioxide    -1.488238
# total sulfur dioxide   -1.985250
# density                -0.443849
# pH                     -0.452141
# sulphates              -0.173921
# alcohol                -0.580471
# quality                 5.000000
# Name: 979, dtype: float64
# fixed acidity          -1.013043
# volatile acidity       -0.875545
# citric acid             3.105664
# residual sugar         -0.964483
# chlorides               4.862626
# free sulfur dioxide    -1.547043
# total sulfur dioxide   -1.961717
# density                -0.443849
# pH                     -0.452141
# sulphates              -0.261553
# alcohol                -0.580471
# quality                 6.000000
# Name: 980, dtype: float64
# fixed acidity          -1.013043
# volatile acidity       -0.875545
# citric acid             3.105664
# residual sugar         -0.964483
# chlorides               4.862626
# free sulfur dioxide    -1.547043
# total sulfur dioxide   -1.961717
# density                -0.443849
# pH                     -0.452141
# sulphates              -0.261553
# alcohol                -0.580471
# quality                 6.000000
# Name: 980, dtype: float64
# fixed acidity          -0.894529
# volatile acidity       -1.173210
# citric acid            -0.530476
# residual sugar          1.224201
# chlorides               0.834380
# free sulfur dioxide     1.628419
# total sulfur dioxide    0.556302
# density                 1.796503
# pH                      3.124369
# sulphates              -0.524447
# alcohol                -1.311884
# quality                 5.000000
# Name: 1014, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        0.910449
# citric acid             1.122315
# residual sugar          0.948151
# chlorides               1.154809
# free sulfur dioxide     0.511127
# total sulfur dioxide   -0.055553
# density                 0.927112
# pH                     -1.379385
# sulphates               3.418971
# alcohol                -1.068080
# quality                 5.000000
# Name: 1016, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        0.612783
# citric acid             3.353583
# residual sugar         -0.708151
# chlorides               1.932992
# free sulfur dioxide    -0.723775
# total sulfur dioxide    1.097558
# density                -0.410411
# pH                      2.130894
# sulphates               1.841604
# alcohol                 1.207427
# quality                 6.000000
# Name: 1024, dtype: float64
# fixed acidity          -0.657501
# volatile acidity        3.192551
# citric acid             0.874397
# residual sugar          0.908715
# chlorides               0.193523
# free sulfur dioxide     0.863956
# total sulfur dioxide    2.509531
# density                 1.060865
# pH                      0.011480
# sulphates               0.702394
# alcohol                -0.986812
# quality                 4.000000
# Name: 1029, dtype: float64
# fixed acidity           1.238723
# volatile acidity        3.589438
# citric acid             1.039676
# residual sugar          0.829844
# chlorides               9.073973
# free sulfur dioxide    -0.135727
# total sulfur dioxide    2.085940
# density                 1.428684
# pH                     -2.107933
# sulphates               2.192130
# alcohol                -1.149348
# quality                 3.000000
# Name: 1034, dtype: float64
# fixed acidity           1.238723
# volatile acidity        3.589438
# citric acid             1.039676
# residual sugar          0.829844
# chlorides               9.073973
# free sulfur dioxide    -0.135727
# total sulfur dioxide    2.085940
# density                 1.428684
# pH                     -2.107933
# sulphates               2.192130
# alcohol                -1.149348
# quality                 3.000000
# Name: 1034, dtype: float64
# fixed acidity           0.764667
# volatile acidity       -1.073988
# citric acid             0.295920
# residual sugar         -0.964483
# chlorides               0.651278
# free sulfur dioxide    -1.017799
# total sulfur dioxide   -1.491059
# density                -0.142907
# pH                      2.329589
# sulphates               3.418971
# alcohol                 0.150942
# quality                 5.000000
# Name: 1036, dtype: float64
# fixed acidity           1.594265
# volatile acidity        3.986326
# citric acid            -0.282557
# residual sugar         -0.846176
# chlorides               0.056196
# free sulfur dioxide    -1.076604
# total sulfur dioxide   -0.008487
# density                 0.325227
# pH                      0.210175
# sulphates               1.929235
# alcohol                 0.232210
# quality                 4.000000
# Name: 1040, dtype: float64
# fixed acidity           0.053583
# volatile acidity       -0.677101
# citric acid             3.932060
# residual sugar         -1.043355
# chlorides               4.175993
# free sulfur dioxide     0.981566
# total sulfur dioxide   -0.361481
# density                -0.276659
# pH                     -1.048226
# sulphates              -0.874973
# alcohol                -1.068080
# quality                 6.000000
# Name: 1051, dtype: float64
# fixed acidity           0.053583
# volatile acidity       -0.677101
# citric acid             3.932060
# residual sugar         -1.043355
# chlorides               4.175993
# free sulfur dioxide     0.981566
# total sulfur dioxide   -0.361481
# density                -0.276659
# pH                     -1.048226
# sulphates              -0.874973
# alcohol                -1.068080
# quality                 6.000000
# Name: 1051, dtype: float64
# fixed acidity           3.016433
# volatile acidity        0.116674
# citric acid             1.783431
# residual sugar         -0.826458
# chlorides               0.193523
# free sulfur dioxide    -1.076604
# total sulfur dioxide   -0.455612
# density                 0.726484
# pH                     -0.452141
# sulphates               1.753972
# alcohol                -0.174131
# quality                 4.000000
# Name: 1053, dtype: float64
# fixed acidity           3.490489
# volatile acidity        0.811227
# citric acid             0.957036
# residual sugar         -0.944765
# chlorides              -0.172682
# free sulfur dioxide    -1.429433
# total sulfur dioxide   -0.337948
# density                 0.124598
# pH                     -1.710543
# sulphates              -0.261553
# alcohol                 0.232210
# quality                 5.000000
# Name: 1123, dtype: float64
# fixed acidity           3.253461
# volatile acidity       -0.478657
# citric acid             0.543838
# residual sugar         -0.964483
# chlorides              -0.081131
# free sulfur dioxide    -0.958994
# total sulfur dioxide   -0.079086
# density                -0.109468
# pH                     -1.511848
# sulphates               0.001342
# alcohol                 0.313478
# quality                 5.000000
# Name: 1124, dtype: float64
# fixed acidity          -0.894529
# volatile acidity        3.192551
# citric acid            -2.761743
# residual sugar         -1.003919
# chlorides              -0.172682
# free sulfur dioxide    -0.664970
# total sulfur dioxide   -1.396928
# density                -0.109468
# pH                      0.806260
# sulphates              -0.962605
# alcohol                -0.905544
# quality                 4.000000
# Name: 1152, dtype: float64
# fixed acidity          -1.368585
# volatile acidity       -0.180992
# citric acid            -0.530476
# residual sugar         -0.451818
# chlorides               7.105626
# free sulfur dioxide     2.245870
# total sulfur dioxide    1.203456
# density                 0.057722
# pH                      0.541334
# sulphates              -0.962605
# alcohol                -0.905544
# quality                 6.000000
# Name: 1158, dtype: float64
# fixed acidity          -1.368585
# volatile acidity       -0.180992
# citric acid            -0.530476
# residual sugar         -0.451818
# chlorides               7.105626
# free sulfur dioxide     2.245870
# total sulfur dioxide    1.203456
# density                 0.057722
# pH                      0.541334
# sulphates              -0.962605
# alcohol                -0.905544
# quality                 6.000000
# Name: 1163, dtype: float64
# fixed acidity           1.594265
# volatile acidity        3.291773
# citric acid             0.957036
# residual sugar         -0.195486
# chlorides              -0.721988
# free sulfur dioxide    -1.194214
# total sulfur dioxide   -0.479145
# density                 0.458979
# pH                     -0.319678
# sulphates              -1.313131
# alcohol                -0.743008
# quality                 5.000000
# Name: 1171, dtype: float64
# fixed acidity           3.490489
# volatile acidity        1.605001
# citric acid             0.543838
# residual sugar         -0.708151
# chlorides              -0.447335
# free sulfur dioxide    -0.018117
# total sulfur dioxide    0.673966
# density                 0.525855
# pH                     -1.445616
# sulphates              -0.874973
# alcohol                -1.068080
# quality                 5.000000
# Name: 1178, dtype: float64
# fixed acidity           1.594265
# volatile acidity        3.291773
# citric acid             0.957036
# residual sugar         -0.195486
# chlorides              -0.721988
# free sulfur dioxide    -1.194214
# total sulfur dioxide   -0.479145
# density                 0.458979
# pH                     -0.319678
# sulphates              -1.313131
# alcohol                -0.743008
# quality                 5.000000
# Name: 1180, dtype: float64
# fixed acidity           3.371975
# volatile acidity       -0.379435
# citric acid             0.957036
# residual sugar         -1.023637
# chlorides              -0.584661
# free sulfur dioxide    -1.429433
# total sulfur dioxide   -1.867585
# density                -0.477287
# pH                     -2.968945
# sulphates              -0.173921
# alcohol                 0.232210
# quality                 6.000000
# Name: 1214, dtype: float64
# fixed acidity            1.357237
# volatile acidity         3.291773
# citric acid              0.378559
# residual sugar           1.125612
# chlorides               11.683178
# free sulfur dioxide     -0.664970
# total sulfur dioxide     1.921209
# density                  1.763065
# pH                      -1.644311
# sulphates               -0.086290
# alcohol                 -1.068080
# quality                  5.000000
# Name: 1217, dtype: float64
# fixed acidity            1.357237
# volatile acidity         3.291773
# citric acid              0.378559
# residual sugar           1.125612
# chlorides               11.683178
# free sulfur dioxide     -0.664970
# total sulfur dioxide     1.921209
# density                  1.763065
# pH                      -1.644311
# sulphates               -0.086290
# alcohol                 -1.068080
# quality                  5.000000
# Name: 1217, dtype: float64
# fixed acidity           3.016433
# volatile acidity       -0.180992
# citric acid             1.618152
# residual sugar         -1.023637
# chlorides               0.056196
# free sulfur dioxide    -0.606165
# total sulfur dioxide   -0.690941
# density                -0.644478
# pH                      0.276407
# sulphates              -1.838920
# alcohol                 1.613768
# quality                 6.000000
# Name: 1228, dtype: float64
# fixed acidity           4.083059
# volatile acidity       -0.280214
# citric acid             1.204955
# residual sugar         -0.826458
# chlorides              -0.172682
# free sulfur dioxide    -0.429751
# total sulfur dioxide    0.603368
# density                 1.328369
# pH                      0.011480
# sulphates               0.877657
# alcohol                -0.661739
# quality                 5.000000
# Name: 1239, dtype: float64
# fixed acidity           1.357237
# volatile acidity        3.787882
# citric acid             3.188304
# residual sugar          2.200236
# chlorides              -0.172682
# free sulfur dioxide     1.569614
# total sulfur dioxide    2.227137
# density                 1.963693
# pH                     -1.776775
# sulphates               1.666341
# alcohol                -0.905544
# quality                 4.000000
# Name: 1245, dtype: float64
# fixed acidity           1.357237
# volatile acidity        3.787882
# citric acid             3.188304
# residual sugar          2.200236
# chlorides              -0.172682
# free sulfur dioxide     1.569614
# total sulfur dioxide    2.227137
# density                 1.963693
# pH                     -1.776775
# sulphates               1.666341
# alcohol                -0.905544
# quality                 4.000000
# Name: 1245, dtype: float64
# fixed acidity          -1.842641
# volatile acidity       -0.180992
# citric acid            -0.861034
# residual sugar         -0.244781
# chlorides              -0.538886
# free sulfur dioxide     0.746346
# total sulfur dioxide    0.509236
# density                 0.392103
# pH                      4.184075
# sulphates               0.176605
# alcohol                -0.011595
# quality                 7.000000
# Name: 1250, dtype: float64
# fixed acidity           0.172097
# volatile acidity       -1.173210
# citric acid             3.270943
# residual sugar         -1.063073
# chlorides               4.221768
# free sulfur dioxide     1.334395
# total sulfur dioxide    0.273907
# density                -0.142907
# pH                     -0.717068
# sulphates              -1.663657
# alcohol                -1.068080
# quality                 5.000000
# Name: 1254, dtype: float64
# fixed acidity           0.172097
# volatile acidity       -1.173210
# citric acid             3.270943
# residual sugar         -1.063073
# chlorides               4.221768
# free sulfur dioxide     1.334395
# total sulfur dioxide    0.273907
# density                -0.142907
# pH                     -0.717068
# sulphates              -1.663657
# alcohol                -1.068080
# quality                 5.000000
# Name: 1254, dtype: float64
# fixed acidity          -0.538987
# volatile acidity       -0.577879
# citric acid             0.048001
# residual sugar         -0.905330
# chlorides               0.513951
# free sulfur dioxide    -0.370946
# total sulfur dioxide   -0.808605
# density                 0.626170
# pH                      4.117844
# sulphates               0.702394
# alcohol                -0.174131
# quality                 6.000000
# Name: 1255, dtype: float64
# fixed acidity          -0.538987
# volatile acidity       -1.073988
# citric acid            -0.530476
# residual sugar          0.060846
# chlorides              -0.447335
# free sulfur dioxide     3.098540
# total sulfur dioxide    1.991808
# density                 0.258351
# pH                      0.607565
# sulphates              -1.225500
# alcohol                -0.255399
# quality                 6.000000
# Name: 1257, dtype: float64
# fixed acidity           3.253461
# volatile acidity        0.116674
# citric acid             1.039676
# residual sugar         -0.974342
# chlorides              -0.310008
# free sulfur dioxide     2.481089
# total sulfur dioxide    1.991808
# density                 0.124598
# pH                     -1.776775
# sulphates              -0.261553
# alcohol                -0.824276
# quality                 6.000000
# Name: 1263, dtype: float64
# fixed acidity           0.172097
# volatile acidity        1.108892
# citric acid            -0.199917
# residual sugar         -0.215204
# chlorides               5.640809
# free sulfur dioxide    -0.194531
# total sulfur dioxide    0.556302
# density                 0.826798
# pH                      0.077712
# sulphates              -0.086290
# alcohol                -0.905544
# quality                 5.000000
# Name: 1272, dtype: float64
# fixed acidity           0.646153
# volatile acidity        0.315117
# citric acid             3.353583
# residual sugar          0.849562
# chlorides              -0.310008
# free sulfur dioxide     0.922761
# total sulfur dioxide    0.203309
# density                 1.228055
# pH                     -1.114458
# sulphates              -0.524447
# alcohol                -1.474421
# quality                 5.000000
# Name: 1282, dtype: float64
# fixed acidity           0.053583
# volatile acidity        1.108892
# citric acid            -0.943673
# residual sugar         -0.412383
# chlorides              -0.721988
# free sulfur dioxide    -1.488238
# total sulfur dioxide   -0.855671
# density                -0.343535
# pH                     -1.246921
# sulphates               3.331340
# alcohol                 0.882355
# quality                 4.000000
# Name: 1293, dtype: float64
# fixed acidity           0.053583
# volatile acidity        1.307336
# citric acid            -0.943673
# residual sugar         -0.432100
# chlorides              -0.676212
# free sulfur dioxide    -1.488238
# total sulfur dioxide   -0.855671
# density                -0.343535
# pH                     -1.246921
# sulphates               3.243708
# alcohol                 0.882355
# quality                 4.000000
# Name: 1294, dtype: float64
# fixed acidity           1.357237
# volatile acidity        3.093329
# citric acid             3.105664
# residual sugar          2.160800
# chlorides              -0.355784
# free sulfur dioxide     1.510809
# total sulfur dioxide    2.109472
# density                 1.997131
# pH                     -1.578080
# sulphates               2.279762
# alcohol                -0.986812
# quality                 5.000000
# Name: 1304, dtype: float64
# fixed acidity           1.357237
# volatile acidity        3.093329
# citric acid             3.105664
# residual sugar          2.160800
# chlorides              -0.355784
# free sulfur dioxide     1.510809
# ...
# residual sugar         -0.018025
# chlorides               0.101972
# free sulfur dioxide    -0.018117
# total sulfur dioxide    0.179776
# density                 0.091160
# pH                     -0.584605
# sulphates               4.558181
# alcohol                -0.011595
# quality                 6.000000
# Name: 4582, dtype: float64
# fixed acidity           0.172097
# volatile acidity        0.513561
# citric acid             3.684141
# residual sugar          0.691818
# chlorides              -0.172682
# free sulfur dioxide    -0.841385
# total sulfur dioxide    2.650729
# density                 0.107879
# pH                     -1.180690
# sulphates               0.527131
# alcohol                 0.394746
# quality                 6.000000
# Name: 4591, dtype: float64
# fixed acidity          -0.183445
# volatile acidity        3.787882
# citric acid            -2.761743
# residual sugar          1.303073
# chlorides              -0.584661
# free sulfur dioxide    -0.194531
# total sulfur dioxide   -1.491059
# density                 0.495761
# pH                     -0.253446
# sulphates               0.088973
# alcohol                 0.150942
# quality                 6.000000
# Name: 4597, dtype: float64
# fixed acidity          -1.013043
# volatile acidity        3.341384
# citric acid            -2.431185
# residual sugar         -1.102508
# chlorides              -0.630437
# free sulfur dioxide    -1.605848
# total sulfur dioxide   -2.079381
# density                -1.226301
# pH                     -0.319678
# sulphates              -0.787342
# alcohol                 0.394746
# quality                 4.000000
# Name: 4609, dtype: float64
# fixed acidity          -0.538987
# volatile acidity        3.390995
# citric acid            -1.770069
# residual sugar         -0.333511
# chlorides               0.651278
# free sulfur dioxide    -0.135727
# total sulfur dioxide    1.356420
# density                 0.512480
# pH                      0.210175
# sulphates              -0.086290
# alcohol                -1.311884
# quality                 5.000000
# Name: 4619, dtype: float64
# fixed acidity          -0.657501
# volatile acidity        0.215896
# citric acid             4.758455
# residual sugar          0.356615
# chlorides              -0.538886
# free sulfur dioxide     0.863956
# total sulfur dioxide    1.427019
# density                -0.029217
# pH                      1.336114
# sulphates               0.001342
# alcohol                 0.963623
# quality                 6.000000
# Name: 4626, dtype: float64
# fixed acidity          -0.657501
# volatile acidity        0.215896
# citric acid             4.758455
# residual sugar          0.356615
# chlorides              -0.538886
# free sulfur dioxide     0.863956
# total sulfur dioxide    1.427019
# density                -0.029217
# pH                      1.336114
# sulphates               0.001342
# alcohol                 0.963623
# quality                 6.000000
# Name: 4632, dtype: float64
# fixed acidity          -0.183445
# volatile acidity        3.291773
# citric acid            -1.026313
# residual sugar         -0.934906
# chlorides               3.260482
# free sulfur dioxide     0.275907
# total sulfur dioxide    2.391867
# density                -0.076030
# pH                     -0.518373
# sulphates               0.702394
# alcohol                -0.986812
# quality                 5.000000
# Name: 4648, dtype: float64
# fixed acidity          -0.183445
# volatile acidity        3.291773
# citric acid            -1.026313
# residual sugar         -0.934906
# chlorides               3.260482
# free sulfur dioxide     0.275907
# total sulfur dioxide    2.391867
# density                -0.076030
# pH                     -0.518373
# sulphates               0.702394
# alcohol                -0.986812
# quality                 5.000000
# Name: 4648, dtype: float64
# fixed acidity          -1.368585
# volatile acidity        4.135158
# citric acid            -2.265906
# residual sugar          0.080564
# chlorides              -0.172682
# free sulfur dioxide    -1.547043
# total sulfur dioxide   -1.279263
# density                 0.097848
# pH                      1.667272
# sulphates              -0.436816
# alcohol                -0.255399
# quality                 5.000000
# Name: 4649, dtype: float64
# fixed acidity          -1.487099
# volatile acidity        4.135158
# citric acid            -2.265906
# residual sugar          0.080564
# chlorides              -0.172682
# free sulfur dioxide    -1.547043
# total sulfur dioxide   -1.279263
# density                 0.097848
# pH                      1.667272
# sulphates              -0.436816
# alcohol                -0.255399
# quality                 5.000000
# Name: 4650, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        3.490216
# citric acid            -2.431185
# residual sugar         -1.003919
# chlorides               0.559727
# free sulfur dioxide    -0.606165
# total sulfur dioxide   -0.126152
# density                -0.440506
# pH                     -0.120983
# sulphates              -0.874973
# alcohol                -0.255399
# quality                 4.000000
# Name: 4680, dtype: float64
# fixed acidity          -0.064931
# volatile acidity        3.490216
# citric acid            -2.431185
# residual sugar         -1.003919
# chlorides               0.559727
# free sulfur dioxide    -0.606165
# total sulfur dioxide   -0.126152
# density                -0.440506
# pH                     -0.120983
# sulphates              -0.874973
# alcohol                -0.255399
# quality                 4.000000
# Name: 4686, dtype: float64
# fixed acidity          -0.894529
# volatile acidity       -1.272432
# citric acid             0.543838
# residual sugar         -1.023637
# chlorides              -0.721988
# free sulfur dioxide    -0.958994
# total sulfur dioxide   -1.279263
# density                -1.594120
# pH                      0.011480
# sulphates               4.120024
# alcohol                 2.020108
# quality                 6.000000
# Name: 4696, dtype: float64
# fixed acidity           0.172097
# volatile acidity       -0.081770
# citric acid             3.353583
# residual sugar         -1.003919
# chlorides               5.823912
# free sulfur dioxide    -0.076922
# total sulfur dioxide   -0.408546
# density                -0.229846
# pH                     -0.981995
# sulphates              -0.261553
# alcohol                -1.068080
# quality                 6.000000
# Name: 4698, dtype: float64
# fixed acidity           0.172097
# volatile acidity       -0.081770
# citric acid             3.353583
# residual sugar         -1.003919
# chlorides               5.823912
# free sulfur dioxide    -0.076922
# total sulfur dioxide   -0.408546
# density                -0.229846
# pH                     -0.981995
# sulphates              -0.261553
# alcohol                -1.068080
# quality                 6.000000
# Name: 4698, dtype: float64
# fixed acidity          -0.538987
# volatile acidity        4.085548
# citric acid            -2.017987
# residual sugar          0.238307
# chlorides              -0.081131
# free sulfur dioxide    -0.076922
# total sulfur dioxide    0.132710
# density                 0.258351
# pH                      0.475102
# sulphates              -0.962605
# alcohol                -0.336667
# quality                 6.000000
# Name: 4701, dtype: float64
# fixed acidity          -0.538987
# volatile acidity        4.085548
# citric acid            -2.017987
# residual sugar          0.238307
# chlorides              -0.081131
# free sulfur dioxide    -0.076922
# total sulfur dioxide    0.132710
# density                 0.258351
# pH                      0.475102
# sulphates              -0.962605
# alcohol                -0.336667
# quality                 6.000000
# Name: 4702, dtype: float64
# fixed acidity          -2.198183
# volatile acidity       -0.379435
# citric acid            -1.191592
# residual sugar         -0.274357
# chlorides              -0.126906
# free sulfur dioxide    -1.076604
# total sulfur dioxide   -0.879204
# density                 0.117911
# pH                      3.190600
# sulphates               0.702394
# alcohol                -0.417935
# quality                 5.000000
# Name: 4744, dtype: float64
# fixed acidity           -0.894529
# volatile acidity        -0.180992
# citric acid             -0.695755
# residual sugar          -0.688433
# chlorides                0.056196
# free sulfur dioxide     14.918314
# total sulfur dioxide     7.098444
# density                 -0.296722
# pH                       1.667272
# sulphates                1.315815
# alcohol                 -0.011595
# quality                  3.000000
# Name: 4745, dtype: float64
# fixed acidity           -0.894529
# volatile acidity        -0.180992
# citric acid             -0.695755
# residual sugar          -0.688433
# chlorides                0.056196
# free sulfur dioxide     14.918314
# total sulfur dioxide     7.098444
# density                 -0.296722
# pH                       1.667272
# sulphates                1.315815
# alcohol                 -0.011595
# quality                  3.000000
# Name: 4745, dtype: float64
# fixed acidity          -0.301959
# volatile acidity        0.116674
# citric acid             3.270943
# residual sugar         -0.826458
# chlorides              -0.859314
# free sulfur dioxide    -0.841385
# total sulfur dioxide   -1.091000
# density                -1.346678
# pH                     -0.452141
# sulphates              -0.086290
# alcohol                 1.532500
# quality                 6.000000
# Name: 4755, dtype: float64
# fixed acidity          -1.013043
# volatile acidity        3.093329
# citric acid            -2.761743
# residual sugar         -1.102508
# chlorides              -0.401559
# free sulfur dioxide    -0.312141
# total sulfur dioxide   -1.020401
# density                -1.239676
# pH                     -0.584605
# sulphates              -0.787342
# alcohol                 0.313478
# quality                 4.000000
# Name: 4779, dtype: float64
# fixed acidity          -3.501837
# volatile acidity       -0.528268
# citric acid             0.543838
# residual sugar         -0.432100
# chlorides              -0.721988
# free sulfur dioxide    -0.370946
# total sulfur dioxide   -0.479145
# density                -1.681059
# pH                      2.528284
# sulphates              -1.137868
# alcohol                 1.857572
# quality                 8.000000
# Name: 4787, dtype: float64
# fixed acidity          -1.605613
# volatile acidity        3.390995
# citric acid            -0.034638
# residual sugar         -0.925047
# chlorides              -0.401559
# free sulfur dioxide    -0.664970
# total sulfur dioxide   -0.479145
# density                -2.155879
# pH                     -0.253446
# sulphates              -0.874973
# alcohol                 2.467083
# quality                 6.000000
# Name: 4789, dtype: float64
# fixed acidity          -2.553725
# volatile acidity        5.028155
# citric acid            -2.761743
# residual sugar         -0.589843
# chlorides              -0.447335
# free sulfur dioxide    -0.723775
# total sulfur dioxide   -0.102619
# density                -1.410210
# pH                      2.263357
# sulphates               3.769497
# alcohol                 2.670253
# quality                 6.000000
# Name: 4792, dtype: float64
# fixed acidity          -2.553725
# volatile acidity        5.028155
# citric acid            -2.761743
# residual sugar         -0.589843
# chlorides              -0.447335
# free sulfur dioxide    -0.723775
# total sulfur dioxide   -0.102619
# density                -1.410210
# pH                      2.263357
# sulphates               3.769497
# alcohol                 2.670253
# quality                 6.000000
# Name: 4792, dtype: float64
# fixed acidity          -1.013043
# volatile acidity        0.315117
# citric acid            -0.117278
# residual sugar          0.198872
# chlorides               5.915463
# free sulfur dioxide     0.687541
# total sulfur dioxide    0.485703
# density                 0.392103
# pH                      0.011480
# sulphates               0.088973
# alcohol                -0.905544
# quality                 6.000000
# Name: 4793, dtype: float64
# fixed acidity          -1.013043
# volatile acidity        0.414339
# citric acid            -0.282557
# residual sugar          0.179154
# chlorides               5.869687
# free sulfur dioxide     0.628736
# total sulfur dioxide    0.485703
# density                 0.388759
# pH                     -0.054751
# sulphates               0.001342
# alcohol                -0.905544
# quality                 5.000000
# Name: 4794, dtype: float64
# fixed acidity          -1.250071
# volatile acidity        0.811227
# citric acid             1.370234
# residual sugar         -1.063073
# chlorides               3.718238
# free sulfur dioxide     1.628419
# total sulfur dioxide    0.932828
# density                -0.637790
# pH                     -0.584605
# sulphates              -0.349184
# alcohol                -0.661739
# quality                 5.000000
# Name: 4813, dtype: float64
# fixed acidity          -0.776015
# volatile acidity        4.780100
# citric acid            -2.679104
# residual sugar         -0.629279
# chlorides              -0.218457
# free sulfur dioxide    -1.017799
# total sulfur dioxide   -0.432079
# density                -1.259739
# pH                      0.077712
# sulphates               3.944761
# alcohol                 2.588985
# quality                 7.000000
# Name: 4815, dtype: float64
# fixed acidity          -0.776015
# volatile acidity        4.780100
# citric acid            -2.679104
# residual sugar         -0.629279
# chlorides              -0.218457
# free sulfur dioxide    -1.017799
# total sulfur dioxide   -0.432079
# density                -1.259739
# pH                      0.077712
# sulphates               3.944761
# alcohol                 2.588985
# quality                 7.000000
# Name: 4815, dtype: float64
# fixed acidity          -1.013043
# volatile acidity       -0.081770
# citric acid             0.543838
# residual sugar         -0.925047
# chlorides              -1.133967
# free sulfur dioxide    -1.017799
# total sulfur dioxide   -1.326329
# density                -1.647621
# pH                      0.342639
# sulphates               4.032392
# alcohol                 2.128466
# quality                 6.000000
# Name: 4818, dtype: float64
# fixed acidity          -1.250071
# volatile acidity        0.811227
# citric acid             1.370234
# residual sugar         -1.063073
# chlorides               3.718238
# free sulfur dioxide     1.628419
# total sulfur dioxide    0.932828
# density                -0.637790
# pH                     -0.584605
# sulphates              -0.349184
# alcohol                -0.661739
# quality                 5.000000
# Name: 4820, dtype: float64
# fixed acidity          -1.368585
# volatile acidity       -0.577879
# citric acid            -0.695755
# residual sugar         -1.043355
# chlorides               0.193523
# free sulfur dioxide     3.627784
# total sulfur dioxide    0.862229
# density                -1.015641
# pH                      1.667272
# sulphates               1.140552
# alcohol                 0.476014
# quality                 6.000000
# Name: 4841, dtype: float64
# fixed acidity          -0.301959
# volatile acidity        1.009670
# citric acid            -0.365197
# residual sugar         -0.787022
# chlorides               4.130217
# free sulfur dioxide    -1.194214
# total sulfur dioxide   -1.067467
# density                -0.223158
# pH                     -0.054751
# sulphates               0.965289
# alcohol                -0.824276
# quality                 5.000000
# Name: 4845, dtype: float64
# fixed acidity          -1.842641
# volatile acidity        3.192551
# citric acid             0.048001
# residual sugar         -0.984201
# chlorides              -0.676212
# free sulfur dioxide    -1.899872
# total sulfur dioxide   -1.844052
# density                -1.834874
# pH                      0.541334
# sulphates              -0.962605
# alcohol                 2.020108
# quality                 6.000000
# Name: 4867, dtype: float64
# fixed acidity          -0.776015
# volatile acidity       -0.677101
# citric acid            -0.447836
# residual sugar         -0.136332
# chlorides              -0.813539
# free sulfur dioxide     0.569932
# total sulfur dioxide   -0.408546
# density                -0.784918
# pH                      0.143944
# sulphates               5.171602
# alcohol                 1.329329
# quality                 7.000000
# Name: 4886, dtype: float64

# %%
len(droplist)
# Out:
# 450

# %%
len(np.unique(droplist))
# Out:
# 396

# %%
outliers = pd.DataFrame(pd.Series(droplist).value_counts())

# %%
pd.Series(droplist).value_counts().value_counts()
# Out:
# 1    346
# 2     47
# 3      2
# 4      1
# dtype: int64

# %%
outliers = outliers[outliers[0] > 1]

# %%
for i in outliers[0]:
    if i == 3:
        print(i.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-326-003d819573ad> in <module>()
#       1 for i in outliers[0]:
#       2     if i == 3:
# ----> 3         print(i.name)
#
# AttributeError: 'numpy.int64' object has no attribute 'name'

# %%
df.drop(np.unique(droplist), inplace=True)

# %%
df.skew()
# Out:
# fixed acidity           0.302459
# volatile acidity        0.748206
# citric acid             0.431076
# residual sugar          0.707949
# chlorides               1.050589
# free sulfur dioxide     0.361900
# total sulfur dioxide    0.270373
# density                 0.260669
# pH                      0.278086
# sulphates               0.647401
# alcohol                 0.443220
# quality                 0.204812
# dtype: float64

# %%
for i in df:
    if i == 'quality':
        break
    df[i] = np.log(df[i])
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log
#   after removing the cwd from sys.path.

# %%
white.max()
# Out:
# fixed acidity            14.20000
# volatile acidity          1.10000
# citric acid               1.66000
# residual sugar           65.80000
# chlorides                 0.34600
# free sulfur dioxide     289.00000
# total sulfur dioxide    440.00000
# density                   1.03898
# pH                        3.82000
# sulphates                 1.08000
# alcohol                  14.20000
# quality                   9.00000
# dtype: float64

# %%
df.max()
# Out:
# fixed acidity           2.897919
# volatile acidity        2.994107
# citric acid             2.940385
# residual sugar          2.841067
# chlorides               2.940054
# free sulfur dioxide     2.980930
# total sulfur dioxide    2.862525
# density                 2.652518
# pH                      2.991905
# sulphates               2.980814
# alcohol                 2.995326
# quality                 9.000000
# dtype: float64

# %%
len(df)
# Out:
# 4504

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-223-22a66f213bbd> in <module>()
# ----> 1 sns.distplot(df)
#
# D:\Anaconda\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     212         hist_color = hist_kws.pop("color", color)
#     213         ax.hist(a, bins, orientation=orientation,
# --> 214                 color=hist_color, **hist_kws)
#     215         if hist_color != color:
#     216             hist_kws["color"] = hist_color
#
# D:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# D:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6181             color = mcolors.to_rgba_array(color)
#    6182             if len(color) != nx:
# -> 6183                 raise ValueError("color kwarg must have one color per dataset")
#    6184
#    6185         # If bins are not specified either explicitly or via range,
#
# ValueError: color kwarg must have one color per dataset

# %%
pls_w = PLSRegression(scale = False)
scores2 = cross_val_score(pls_w, df.iloc[:,:-1], df.iloc[:,-1], cv=5, scoring = 'neg_mean_absolute_error')
scores2.mean()
# Out:
# -0.59707279262127011

# %%
scores0.mean()
# Out:
# -0.65975635707539537

# %%
scores1.mean()
# Out:
# -0.60284431780022429

# %%
logdata = white.copy()

# %%
for i in logdata:
    if i == 'quality':
        break
    logdata[i] = np.log1p(logdata[i])

# %%
logdata.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       2.079442          0.239017     0.307485        3.077312   0.044017
# 1       1.987874          0.262364     0.292670        0.955511   0.047837
# 2       2.208274          0.246860     0.336472        2.066863   0.048790
# 3       2.104134          0.207014     0.277632        2.251292   0.056380
# 4       2.104134          0.207014     0.277632        2.251292   0.056380
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             3.828641              5.141664  0.693647  1.386294   0.371564
# 1             2.708050              4.890349  0.690143  1.458615   0.398776
# 2             3.433987              4.584967  0.690694  1.449269   0.364643
# 3             3.871201              5.231109  0.690945  1.432701   0.336472
# 4             3.871201              5.231109  0.690945  1.432701   0.336472
#
#     alcohol  quality
# 0  2.282382        6
# 1  2.351375        6
# 2  2.406945        6
# 3  2.388763        6
# 4  2.388763        6

# %%
pls_w = PLSRegression(scale = False)
scores3 = cross_val_score(pls_w, logdata.iloc[:,:-1], logdata.iloc[:,-1], cv=5, scoring = 'neg_mean_absolute_error')
scores3.mean()
# Out:
# -0.65643798671197184

# %%
for i in logdata:
    if i == 'quality':
        break
    logdata[i] = StandardScaler().fit_transform(logdata[i].values.reshape(-1,1))

droplist1= []

for i in range(len(logdata)):
    for j in logdata.iloc[i,:-1]:
        if j >= 3 or j <= -3:
            droplist1.append(i)
            
print(len(droplist1))
print(len(np.unique(droplist1)))
# Out:
# 467
# 398

# %%
logdata.drop(np.unique(droplist1), inplace=True)

# %%
logdata.max()
# Out:
# fixed acidity           2.971091
# volatile acidity        2.982752
# citric acid             2.944863
# residual sugar          2.136731
# chlorides               2.912654
# free sulfur dioxide     2.917414
# total sulfur dioxide    2.877355
# density                 2.979796
# pH                      2.997693
# sulphates               2.945852
# alcohol                 2.695434
# quality                 9.000000
# dtype: float64

# %%
pls_w = PLSRegression(scale = False)
scores4 = cross_val_score(pls_w, logdata.iloc[:,:-1], logdata.iloc[:,-1], cv=5, scoring = 'neg_mean_absolute_error')
scores4.mean()
# Out:
# -0.65343564846419577

# %%
for i in logdata:
    print(i)
# Out:
# fixed acidity
# volatile acidity
# residual sugar
# chlorides
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# quality

# %%
logdata.drop(['citric acid','free sulfur dioxide'], inplace=True, axis=1)

# %%
df.drop(['alcohol','total sulfur dioxide', 'residual sugar'], inplace=True, axis=1)

# %%
logdata.skew()
# Out:
# fixed acidity          0.078831
# volatile acidity       0.581200
# citric acid            0.372892
# residual sugar        -0.037679
# chlorides              0.921138
# free sulfur dioxide   -0.600984
# pH                     0.212478
# sulphates              0.465055
# alcohol                0.303660
# quality                0.220441
# dtype: float64

# %%
df.skew()
# Out:
# fixed acidity          0.302459
# volatile acidity       0.748206
# citric acid            0.431076
# chlorides              1.050589
# free sulfur dioxide    0.361900
# density                0.260669
# pH                     0.278086
# sulphates              0.647401
# quality                0.204812
# dtype: float64
